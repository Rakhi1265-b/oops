# %%
#INHERETENCE:
#single inheretence
class Student:
    def profile():
        print("Rakesh\nECE")
class stu(Student):
    pass
s=stu
s.profile()
# Out:
# Rakesh
# ECE

# %%
class Student:
    def __init__(self,name,id,branch):
        self.name=name
        self.id=id
        self.branch=branch
    def display(self):
        print(self.name)
        print(self.id)
        print(self.branch)
class profiling(Student):
    def profile(self):
        print("DETAILS OF STUDENTS")
    def display(self):
        print(self.name)
        print(self.id)
        print(self.branch)

s1=profiling("Rakesh","B201265","ECE")
s1.profile()
s1.display()
s2=Student("Raistar","B201222","CSE")
print()
s2.display()
# Out:
# DETAILS OF STUDENTS
# Rakesh
# B201265
# ECE
#
# Raistar
# B201222
# CSE

# %%
class Student:
    def __init__(self,name,id,branch):
        self.name=name
        self.id=id
        self.branch=branch
    def display(self):
        print(self.name)
        print(self.id)
        print(self.branch)
class profiling(Student):
    def profile(self):
        print("DETAILS OF STUDENTS")
    def display(self):
        super().display()

s1=profiling("Rakesh","B201265","ECE")
s1.profile()
s1.display()
s2=Student("Raistar","B201222","CSE")
print()
s2.display()
# Out:
# DETAILS OF STUDENTS
# Rakesh
# B201265
# ECE
#
# Raistar
# B201222
# CSE

# %%
class Student:
    def __init__(self,name,id,branch):
        self.name=name
        self.id=id
        self.branch=branch
    def display(self):
        print(self.name)
        print(self.id)
        print(self.branch)
class profiling(Student):
    def profile(self):
        print("DETAILS OF STUDENTS")
    def __init__(self, name, id, branch,percentage):
        super().__init__(name, id, branch)
        self.percentage=percentage
    def display(self):
        super().display()
        print(self.percentage)
        

s1=profiling("Rakesh","B201265","ECE",69.01)
s1.profile()
s1.display()
s2=Student("Raistar","B201222","CSE")
print()
s2.display()
# Out:
# DETAILS OF STUDENTS
# Rakesh
# B201265
# ECE
# 69.01
#
# Raistar
# B201222
# CSE

# %%
class Cse:
    def about(self):
        print("COMPUTER SCIENCE AND ENGINEERING")
    def oppertunity(self):
        print("Testing \nDeveloper \nR&D")
class Ece:
    def detial(self):
        print("ELECTRIONICS AND COMMUNICATIONS ENGINEERING ")
    def oppertunity(self):
        print("Designing \nWireless communications \nR&D")
class Eng(Cse,Ece):
      pass
p=Eng()
p.about()
print("OPPERTUNITY: ")
Cse.oppertunity(p)
print()
p.detial()
print("OPPERTUNITY: ")
Ece.oppertunity(p)
# Out:
# COMPUTER SCIENCE AND ENGINEERING
# OPPERTUNITY:
# Testing
# Developer
# R&D
#
# ELECTRIONICS AND COMMUNICATIONS ENGINEERING
# OPPERTUNITY:
# Designing
# Wireless communications
# R&D

# %%
class Cse:
    def __init__(self,cutof,percent):
        self.cutof=cutof
        self.percent=percent
        
    def about(self):
        print("COMPUTER SCIENCE AND ENGINEERING")
    def oppertunity(self):
        print("Testing \nDeveloper \nR&D")
    
class Ece:
    def __init__(self,cutof,percent):
        self.cutof=cutof
        self.percent=percent
        
    def detial(self):
        print("ELECTRIONICS AND COMMUNICATIONS ENGINEERING ")
    def oppertunity(self):
        print("Designing \nWireless communications \nR&D")
class Eng(Cse,Ece):
      def __init__(self,cutof,percent,category):
          Cse.__init__(self,cutof,percent)
          Ece.__init__(self,cutof,percent)
          self.category=category
      def display(self):
          print("The Category you are:",self.category)
      @staticmethod
      def qualify(cutof):
          if(cutof>=9.8):
              print("your Qulifiyed for CSE and CSE")
          elif(cutof>=9.6):
              print("your  Qulified for ECE")
          else:
              print("your not Qulified")



p=Eng(9.51,"95.1%","BC-B")
p.about()
p.display()
print("OPPERTUNITY: ")
Cse.oppertunity(p)
print()
p.detial()
p.display()

print("OPPERTUNITY: ")
Ece.oppertunity(p)
# Out:
# COMPUTER SCIENCE AND ENGINEERING
# The Category you are: BC-B
# OPPERTUNITY:
# Testing
# Developer
# R&D
#
# ELECTRIONICS AND COMMUNICATIONS ENGINEERING
# The Category you are: BC-B
# OPPERTUNITY:
# Designing
# Wireless communications
# R&D

# %%
class Cse:
    def __init__(self):
        self.cutoff=9.80
        self.percentt="98.00%"
        
    def about(self):
        print("COMPUTER SCIENCE AND ENGINEERING")
    def oppertunity(self):
        print("Testing \nDeveloper \nR&D")
    
class Ece:
    def __init__(self):
        self.cutof=9.51
        self.percent="95.10%"
        
    def detial(self):
        print("ELECTRIONICS AND COMMUNICATIONS ENGINEERING ")
    def oppertunity(self):
        print("Designing \nWireless communications \nR&D")
class Eng(Cse,Ece):
      def __init__(self,category):
          Cse.__init__(self)
          Ece.__init__(self)
          self.category=category
          
      def display(self):
          print("The Category you are:",self.category)
      def qualify(self, cgpa):

        if cgpa >= 9.8:
            print("congrats! your selected for CSE and ECE. ")
            print("\n--- CSE ---")
            self.about()
            print("Cutoff:", self.cutoff)
            print("Percentage:", self.percentt)
            print("OPPORTUNITIES:")
            Cse.oppertunity(self)

            print("\n--- ECE ---")
            self.detial()
            print("Cutoff:", self.cutof)
            print("Percentage:", self.percent)
            print("OPPORTUNITIES:")
            Ece.oppertunity(self)

        elif cgpa >= 9.6:
            print("congrats! your selected for ECE. ")

            print("\n--- ECE ---")
            self.detial()
            print("Cutoff:", self.cutof)
            print("Percentage:", self.percent)
            print("OPPORTUNITIES:")
            Ece.oppertunity(self)

        else:

            print("You are not qualified for any branch")

your_cgpa=float(input("Enter your cgpa: "))
clg=input("Enter prefered University: ")
p=Eng(clg)
print("the University your selected :",clg)
p.qualify(your_cgpa)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 60
#      56         else:
#      57
#      58             print("You are not qualified for any branch")
#      59
# ---> 60 your_cgpa=float(input("Enter your cgpa: "))
#      61 clg=input("Enter prefered University: ")
#      62 p=Eng(clg)
#      63 print("the University your selected :",clg)
#
# ValueError: could not convert string to float: 'bv'

# %%
class Human:
    def display1(self):
        print("Halo Human")
class male(Human):
    def display2(self):
        print("halo male")
class female(male):
    def display1(self):
        Human.display1(self)
        male.display2(self)
        # super().display2()
        # super().display1()
        print("halo female")
a=female()
a.display1()  
# a.display2()    
# a.display1()

# %%
class Human:
    def __init__(self,heart):
        self.eyes=2
        self.heart=heart

    def display1(self):
        print("Halo Human")
class male(Human):
    def __init__(self, heart,brain):
        super().__init__( heart)
        self.brain=brain
    def display2(self):
        print("halo male")
class female(male):
    def __init__(self, heart, brain,hands):
        super().__init__( heart, brain)
        self.hands=hands
    def display3(self):
        Human.display1(self)
        male.display2(self)
        print("halo female")
        print("eyes: ",self.eyes)
        print("heart: ",self.heart)
        print("brain: ",self.brain)
        print("hands: ",self.hands)
a=female(1,1,2)
a.display3()  
# a.display2()    
# a.display1()

# %%
class BankAccount:
    bank="SBI"
    def __init__(self,account_holder,acc_num,balance):
        self.account_holder=account_holder
        self.acc_num=acc_num
        self.balance=balance
    def deposit(self,amount):
        self.balance+=amount
        print(self.balance)
class SavingAcount(BankAccount):
    bank="SBI"
    def __init__(self,account_holder,acc_num,balance,intrest):
        super().__init__(account_holder,acc_num,balance)
        self.intrest=intrest
    def total(self):
        self.balance=self.balance+(self.balance*self.intrest)
        print(self.account_holder)
        print(self.acc_num)
        print(self.balance)
    @classmethod
    def change(cls,new_bank):
        cls.bank=new_bank




b=BankAccount("rakesh",12347909,20000)
a=SavingAcount("rakesh",12347909,20000,0.3)    
a.deposit(2000)
a.total()
SavingAcount.change("Union Bank")
print(SavingAcount.bank)

# %%
# Questions On Generator
# 1.	Write a generator that yields numbers from 1 to N.
def u(start,end):
    while(start<=end):
        value=start
        yield value
        start+=1
for i in u(1,10):
    print(i)

# %%
# 2.	Write a generator that yields even numbers from 1 to N
def u(start,end):
    while(start<=end):
        if start%2==0:
            value=start
            yield value
            start+=1
        start+=1
for i in u(1,10):
    print(i)

# %%
# 3.	Write a generator that yields each character of a string.
def gen(st):
    start=st
    index=0
    while(index<len(start)):
        yield start[index]
        index+=1
for i in gen(list("rakesh")):
    print(i)

# %%
# 4.	Write a generator that yields characters of a string in reverse order.
def gen(st):
    start=st
    index=-1
    while(index>=(-1*len(start))):
        yield start[index]
        index-=1
for i in gen(list("rakesh")):
    print(i)

# %%
# 5.	Write a generator that yields only vowels from a string.
def gen(st):
    start=st
    index=0
    while(index<len(start)):
        if start[index] in "aeiou":
            yield start[index]
            index+=1
        index+=1
for i in gen(list("rakesh")):
    print(i)

# %%
# 6.	Write a generator that yields only digits present in a string.
def gen(st):
    start=st
    index=0
    while(index<len(start)):
        if start[index] in "1234567890":
            yield start[index]
        index+=1
        
for i in gen(list("rake90sh1265")):
    print(i)

# %%
# 7.	Write a generator that yields the square of each element in a list.
def gen(st):
    start=st
    index=0
    while(index<len(start)):
        yield start[index]**2
        index+=1
l=[1,2,3,4,5,6,1,2]
for i in gen(l):
    print(i,end=" ")

# %%
# 8.	Write a generator that yields digits from an integer one by one.
def gen(st):
    start=st
    m=0
    while(start!=0):
        r=start%10
        m=m*10+r
        start=start//10
    start=m
    while(start!=0):
        s=start%10
        yield s
        start=start//10
l=143
for i in gen(l):
    print(i,end=" ")

# %%
# 9.	Create a generator that yields cumulative sum of numbers in a list. Example: [1,2,3] → 1, 3, 6
def gen(start):
    sum=0
    i=0
    while(i<len(start)):
        sum=sum+start[i]
        yield sum
        i+=1
for i in gen([1,2,3]):
    print(i,end=" ")

# %%
# Questions On Iterator

# 1.	Create an custom iterator that prints numbers from 1 to N, where N is given by the user.

class counter:
    def __init__(self,end,st):
        self.end=end
        self.st=st
    def __iter__(self):
        return self
    def __next__(self):
        while(self.st<self.end):
            value=self.st
            self.st+=1
            return value
        raise StopIteration
for i in counter(10,1):
    print(i)

# %%
# 2.	Create an custom iterator that prints numbers from N to 1.
class counter:
    def __init__(self,end,st):
        self.end=end
        self.st=st
    def __iter__(self):
        return self
    def __next__(self):
        while(self.end>=self.st):
            value=self.end
            self.end-=1
            return value
        raise StopIteration
for i in counter(10,1):
    print(i)

# %%
# 3.	Create an custom iterator that prints the first N even numbers.

class counter:
    def __init__(self,end,st):
        self.end=end
        self.st=st
    def __iter__(self):
        return self
    def __next__(self):
        while(self.st<=self.end):
            if self.st%2==0:
                value=self.st
                self.st+=1
                return value
            self.st+=1
        raise StopIteration
for i in counter(10,1):
    print(i)

# %%
# 4.	Create an custom iterator that prints the first N odd numbers.

class counter:
    def __init__(self,end,st):
        self.end=end
        self.st=st
    def __iter__(self):
        return self
    def __next__(self):
        while(self.st<=self.end):
            if self.st%2!=0:
                value=self.st
                self.st+=1
                return value
            self.st+=1
        raise StopIteration
for i in counter(10,1):
    print(i)

# %%
# 5.	Create an custom iterator that returns only even numbers from a given list.
class counter:
    def __init__(self,l):
        self.current=l
        self.index=0
    def __iter__(self):
        return self
    def __next__(self):
        while(self.index<len(self.current)):
            if self.current[self.index]%2==0:
                Value=self.current[self.index]
                self.index+=1
                return Value
            self.index+=1
        raise StopIteration
for i in counter([1,2,3,4,4,4,5,6,2]):
    print(i)

# %%
# 6.	Create an custom iterator that returns only odd numbers from a given list.
class counter:
    def __init__(self,l):
        self.current=l
        self.index=0
    def __iter__(self):
        return self
    def __next__(self):
        while(self.index<len(self.current)):
            if self.current[self.index]%2!=0:
                Value=self.current[self.index]
                self.index+=1
                return Value
            self.index+=1
        raise StopIteration
for i in counter([1,2,3,4,4,4,5,6,2]):
    print(i)

# %%
# 7.	Create an custom iterator that returns only positive numbers from a list.
class counter:
    def __init__(self,l):
        self.current=l
        self.index=0
    def __iter__(self):
        return self
    def __next__(self):
        while(self.index<len(self.current)):
            if self.current[self.index]>=0:
                Value=self.current[self.index]
                self.index+=1
                return Value
            self.index+=1
        raise StopIteration
for i in counter([1,2,3,4,4,4,5,6,2]):
    print(i)

# %%
# 8.	Create an custom iterator that prints each character of a string one by one.
class counter:
    def __init__(self,l):
        self.current=l
        self.index=0
    def __iter__(self):
        return self
    def __next__(self):
        while(self.index<len(self.current)):
                Value=self.current[self.index]
                self.index+=1
                return Value
        raise StopIteration
a="rakesh"
for i in counter(list(a)):
    print(i)

# %%
# 9.	Create an custom iterator that prints the characters of a string in reverse order.
class counter:
    def __init__(self,l):
        self.current=l
        self.index=-1
    def __iter__(self):
        return self
    def __next__(self):
        while(self.index>=(-1*len(self.current))):
                Value=self.current[self.index]
                self.index-=1
                return Value
        raise StopIteration
a="rakesh"
for i in counter(list(a)):
    print(i)

# %%
# All 8 Questions on Methods
# 1. Instance Method
# Create a Student class with the instance variables name, age, and marks. Write an instance method display_details() to print all the student's details.
# 2. Instance Method
# Create a BankAccount class with instance variables account_holder and balance. Write an instance method deposit(amount) to add the given amount to the balance and display the updated balance.
# 3. Instance Method
# Create an Employee class with instance variables emp_id, name, and salary. Write an instance method increment_salary(amount) to increase the employee's salary by the given amount.
# 4. Class Method
# Create an Employee class with a class variable company = "Infosys". Write a class method change_company(new_company) to change the company name.
# 5. Class Method
# Create a Bank class with a class variable bank_name = "SBI". Write a class method change_bank(new_bank) to update the bank name.
# 6. Class Method
# Create a Hospital class with a class variable hospital_name = "City Hospital". Write a class method change_hospital(new_name) to update the hospital name.
# 7. Static Method
# Create a Voting class. Write a static method is_eligible(age). If age is 18 or above, print "Eligible to Vote". Otherwise, print "Not Eligible".
# 8. Static Method
# Create a MovieTicket class. Write a static method ticket_price(age).
# Rules:
# - Age below 12 → ₹100
# - Age between 12 and 60 → ₹200
# - Age above 60 → ₹150
# Return the ticket price.
# 9. Static Method
# Create a DeliveryService class. Write a static method delivery_charge(amount).
# Rules:
# - Amount ≥ ₹500 → Free Delivery
# - Otherwise → ₹50 Delivery Charge
# Return the delivery charge.

# %% [markdown]
# # Questions on Methods
#
# ## 1. Instance Method
#
# Create a `Student` class with the instance variables `name`, `age`, and `marks`. Write an instance method `display_details()` to print all the student's details.
#
# ---

# %%
class Student:
    def __init__(self,name,age,marks):
        self.name=name
        self.age=age
        self.marks=marks
    def display(self):
        print("Name :",self.name)
        print("Age  :",self.age)
        print("Marks:",self.marks)
a=Student("rakesh",23,69.1)
a.display()

# %% [markdown]
# ## 2. Instance Method
#
# Create a `BankAccount` class with instance variables `account_holder` and `balance`. Write an instance method `deposit(amount)` to add the given amount to the balance and display the updated balance.
#
# ---

# %%
class BankAccount:
    def __init__(self,acct_holder,bal):
        self.acct_holder=acct_holder
        self.bal=bal
    def deposit(self,amount):
        self.bal+=amount
        print("Account Holder Number  :",self.acct_holder)
        print("Present Account Balance:",self.bal)
b=BankAccount("Rakesh",20000)
b.deposit(3000)

# %% [markdown]
# ## 3. Instance Method
#
# Create an `Employee` class with instance variables `emp_id`, `name`, and `salary`. Write an instance method `increment_salary(amount)` to increase the employee's salary by the given amount.
#
# ---

# %%
class Employye:
    def __init__(self,emp_id,name,salary):
        self.emp_id=emp_id
        self.name=name
        self.salary=salary
    def increment_salary(self,amount):
        self.salary+=amount
        print(self.emp_id)
        print(self.name)
        print(self.salary)
e=Employye(201265,"Rakesh",20000)
e.increment_salary(2000)

# %% [markdown]
# ## 4. Class Method
#
# Create an `Employee` class with a class variable `company = "Infosys"`. Write a class method `change_company(new_company)` to change the company name.
#
# ---

# %%
class Employye:
    company="Infosys"
    @classmethod
    def change_company(cls,new):
        cls.company=new
Employye.change_company("TCS")
print(Employye.company)

# %% [markdown]
# ## 5. Class Method
#
# Create a `Bank` class with a class variable `bank_name = "SBI"`. Write a class method `change_bank(new_bank)` to update the bank name.
#
# ---

# %% [markdown]
# ## 6. Class Method
#
# Create a `Hospital` class with a class variable `hospital_name = "City Hospital"`. Write a class method `change_hospital(new_name)` to update the hospital name.
#
# ---

# %% [markdown]
# ## 7. Static Method
#
# Create a `Voting` class. Write a static method `is_eligible(age)`.
#
# - If age is `18` or above, print `"Eligible to Vote"`.
# - Otherwise, print `"Not Eligible"`.
#
# ---

# %%
class Voting:
    @staticmethod
    def is_eligible(age):
        if(age>=18):
            print("Eligible to Vote")
        else:
            print("Not Eligible")
Voting.is_eligible(18)

# %% [markdown]
# ## 8. Static Method
#
# Create a `MovieTicket` class. Write a static method `ticket_price(age)`.
#
# ### Rules
#
# - Age below `12` → ₹100
# - Age between `12` and `60` → ₹200
# - Age above `60` → ₹150
#
# Return the ticket price.
#
# ---

# %% [markdown]
# ## 9. Static Method
#
# Create a `DeliveryService` class. Write a static method `delivery_charge(amount)`.
#
# ### Rules
#
# - Amount ≥ ₹500 → Free Delivery
# - Otherwise → ₹50 Delivery Charge
#
# Return the delivery charge.
#
# ---

# %% [markdown]
# ### DUNDER METHODS:

# %%
class length:
    def __init__(self,l):
        self.l=l
    def __len__(self):
        return len(self.l)
    def __contains__(self, item):
        return item in self.l
l=[1,2,3,4,10]
m=length(l)
print(len(m))
print(100 in l)

# %%
class calculater:
    def __init__(self,a):
        self.a=a
    def __add__(self, other):
        return calculater(self.a + other.a)
    def __sub__(self, other):
        return calculater(self.a-other.a)
    def __mul__(self, other):
        return calculater(self.a*other.a)
    def __truediv__(self, other):
        return calculater(self.a/other.a)
    def __mod__(self, other):
        return calculater(self.a%other.a)
    def __floordiv__(self, other):
        return calculater(self.a//other.a)
    def __str__(self):
        return str(self.a)
a=calculater(10)
b=calculater(5)
add=a+b
print(add)
sub=a-b
print(sub)
print(a*b)
print(a%b)
print(a/b)
print(a//b)

# %%
class calculater:
    def __init__(self,a):
        self.a=a
    def __hash__(self):
        return hash(self.a)
k=calculater("rakes1")
print(hash(k))

# %%
class Calculator:
    def __call__(self, a, b):
        return a + b

c = Calculator()

print(c(10, 20))

class Greeting:
    def __call__(self):
        print("Hello!")

g = Greeting()

g()

# %%
# Question 1: 
# Bank Account Operations
# Create a class BankAccount with:
# •	attributes: account_holder, balance 
# •	instance method: deposit(amount) 
# •	instance method: withdraw(amount) 
# Implement these magic methods:
# •	__str__() → display account details 
# •	__add__() → add balances of two accounts 
# •	__sub__() → subtract balances 
# •	__eq__() → compare if two accounts have same balance 
# •	__lt__() → check which account has lower balance 
# •	__getattribute__() → print a message whenever an attribute is accessed 
# •	__setattr__() → prevent setting negative balance 
# Demonstrate creating two accounts and using all operations.

# %%
class BankAccount:
    def __init__(self,account_holder,balance):
        self.account_holder=account_holder
        self.balance=balance
    def deposit(self,amount):
        self.balance+=amount
    
    def withdraw(self,amount):
        self.balance-=amount
    def __str__(self):
        return str(self.account_holder)
    def __add__(self, other):
        return (self.balance+other.balance)
    def __sub__(self, other):
        return (self.balance-other.balance)
    def __eq__(self, value):
        return (self.balance==value.balance)
    def __lt__(self, other):
        return (self.balance<other.balance)

a=BankAccount("Rakesh",50000)
b=BankAccount("Raistar",30000)
a.deposit(1000)
b.deposit(2000)
a.withdraw(1000)
b.deposit(2000)
add=a+b
print(add)
sub=a-b
print(sub)
print(a==b)
print(a<b)

# %% [markdown]
# # Question 2: Product Price Comparison
#
# Create a class `Product` with:
#
# - Attributes:
#   - `name`
#   - `price`
#   - `quantity`
#
# - Method:
#   - `total_price()`
#
# ## Implement the following magic methods:
#
# - `__str__()` → Display the product details.
# - `__add__()` → Add the total prices of two products.
# - `__mul__()` → Multiply the product price by a number.
# - `__gt__()` → Compare which product has a greater total value.
# - `__eq__()` → Compare the prices of two products.
# - `__getattr__()` → Return `"Attribute not found"` for missing attributes.
# - `__setattr__()` → Do not allow the price to be less than `0`.
#
# ## Solution

# %%
class Product:
    def __init__(self,name,price,quantity):
        self.name=name
        self.price=price
        self.quantity=quantity

    def total(self):
        return self.price*self.quantity
    def __str__(self):
        return f"{self.name}\n {self.total}\n {self.quantity}"
    def __add__(self, other):
        return (self.total()+other.total())
    def __mul__(self,number):
        return (self.total()*number)
    def __gt__(self, other):
        return (self.total() > other.total())
    def __eq__(self, value):
        return (self.total==value.total)
a=Product("Boost",5,10)
b=Product("Complain",10,3)        
add=a+b
print(add)
mul=a*2
print(mul)
print(a>b)
print(a==b)

# %% [markdown]
# ---
#
# # Question 3: Student Marks
#
# Create a class `Student` with:
#
# - Attributes:
#   - `name`
#   - `marks`
#
# - Method:
#   - `grade()`
#
# ## Implement the following magic methods:
#
# - `__str__()` → Display the student details.
# - `__add__()` → Add the marks of two students.
# - `__truediv__()` → Divide marks by a number.
# - `__ge__()` → Check if one student scored greater than or equal to another student.
# - `__lt__()` → Check if one student scored less than another student.
# - `__getattribute__()` → Track attribute access.
# - `__setattr__()` → Marks must be between `0` and `100`.
#
# ## Solution
#
# ```python
# # Write your solution here
# ```

# %%
class Student:
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
    def grade(self):
        if self.marks>75:
            return "First class"
        elif(self.marks>45):
            return "Second Class"
        elif(self.marks>35):
            return "pass"
        else:
            return "Fail"
    def __str__(self):
        return f"{self.name} \n {self.marks}"
    def __add__(self, other):
        return Student(self.marks+other.marks)
    def __truediv__(self, num):
        return Student(self.marks/num)
    def __ge__(self, other):
        return Student(self.marks>=other.marks)
    def __lt__(self, other):
        return Student(self.marks< other.marks)
a=Student("Rakesh",61.9)
b=Student("Raistar",45.0)
c=Student("Ravi",29.0)
print(a)
print(b)
print(c)
print(a.grade())
print(b.grade())
print(c.grade())

add=a.marks+b.marks
print(add)
div=a/2
print(div)
div=b/2
print(div)
print(a>=b)
print(a<b)

# %% [markdown]
# ---
#
# # Question 4: Rectangle Area Comparison
#
# Create a class `Rectangle` with:
#
# - Attributes:
#   - `length`
#   - `breadth`
#
# - Method:
#   - `area()`
#
# ## Implement the following magic methods:
#
# - `__str__()` → Display the rectangle details.
# - `__add__()` → Add the areas of two rectangles.
# - `__sub__()` → Subtract the areas of two rectangles.
# - `__eq__()` → Compare the areas of two rectangles.
# - `__gt__()` → Check which rectangle has the larger area.
# - `__getattr__()` → Handle missing attributes.
# - `__setattr__()` → Length and breadth must be positive.
#
# ## Solution
#
# ```python
# # Write your solution here
# ```
#
# ---
# ```

# %%
class Rectangle:
    def __init__(self,length,breadth):
        self.length=length
        self.breadth=breadth
    def area(self):
        return self.length*self.breadth

    def __str__(self):
        return area()
    def __add__(self, other):
        return self.area()+other.area()
    def __sub__(self, other):
        return self.area()-other.area()
    def __eq__(self, value):
        return self.area()==value.area()
    def __gt__(self, other):
        return self.area()>other.area()
a=Rectangle(5,10)
b=Rectangle(2,4)
c=Rectangle(10,30)
print(a.area())
print(b.area())
print(c.area())
add=a+b
print(add)
sub=a-b
print(sub)
print(a==b)
print(a>b)

# %% [markdown]
# # Question 5: Employee Salary System
#
# Create a class `Employee` with:
#
# - Attributes: `name`, `salary`
# - Method: `annual_salary()`
#
# Implement:
#
# - `__str__()`
# - `__add__()` → Add salaries of two employees
# - `__mul__()` → Calculate salary after multiplying by months
# - `__ne__()` → Check if salaries are not equal
# - `__le__()` → Check if one salary is less than or equal to another
# - `__getattribute__()` → Log every attribute access
# - `__setattr__()` → Salary cannot be below `10000`

# %%
class Employee:
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary
    def annual_salary(self):
        self.salary*=12
    def __str__(self):
        return f"Name  :{self.name}\nSalary:{self.salary} \n  "
    def __add__(self, other):
        return Employee(self.salary+other.salary)
    def __mul__(self, other):
        return Employee(self.salary*other.salary)
    def __ne__(self, value):
        return Employee(self.salary!=value.salary)
    def __le__(self, other):
        return Employee(self.salary<other.salary)
emp1=Employee("Rakesh",45000)
emp2=Employee("Raistar",50000)
emp3=Employee("Raistar",50000)

print(emp1)
print(emp2)
print(emp3)
print(emp1.salary+emp2.salary+emp3.salary)
print(emp1.salary*emp2.salary*emp3.salary) 
print(emp1.salary!=emp2.salary)
print(emp1.salary<emp2.salary)

# %% [markdown]
# ---
#
# # Question 6: Book Object Comparison
#
# Create a class `Book` with:
#
# - Attributes: `title`, `author`, `pages`
# - Method: `reading_time()`
#
# Assume `1 page = 2 minutes`.
#
# Implement:
#
# - `__str__()`
# - `__add__()` → Add pages of two books
# - `__floordiv__()` → Divide pages by number of days
# - `__gt__()` → Compare books based on pages
# - `__eq__()` → Compare books based on title
# - `__getattr__()` → Return custom message for missing attribute
# - `__setattr__()` → Title cannot be empty and pages must be positive

# %%
class Book:
    def __init__(self,title,author,pages):
        self.title=title
        self.author=author
        self.pages=pages
 
    def __str__(self):
        return f"Title :{self.title}\nAuthor :{self.author}\nPages  :{self.pages} \n "
    def __add__(self, other):
        return Book(self.pages+other.pages)
    def __floordiv__(self, days):
        return Book(self.pages//days)
    def __gt__(self, other):
        return Book(self.pages>other.pages)
    def __eq__(self, value):
        return Book(self.title==value.title)
    def reading_time(self):
        self.pages=self.pages*2
        return f"{self.pages} mins"
a=Book("Maths","Hari",1500)
b=Book("Science","Naresh",200)
print(a.reading_time())
print(b.reading_time())
print(a)
print(b)
add=a.pages+b.pages
print(add)
print(a.pages//20)
print(b.pages//30)
print(a.pages>b.pages)
print(a.title==b.title)

# %% [markdown]
# ---
#
# # Question 7: Shopping Cart
#
# Create a class `CartItem` with:
#
# - Attributes: `item_name`, `price`, `quantity`
# - Method: `final_amount()`
#
# Implement:
#
# - `__str__()`
# - `__add__()` → Add final amounts of two cart items
# - `__mod__()` → Find remainder after applying a discount value
# - `__lt__()` → Compare item total amount
# - `__ge__()` → Compare quantity
# - `__getattribute__()` → Display which attribute is being accessed
# - `__setattr__()` → Quantity cannot be less than `1`

# %%
class CartItem:
    def __init__(self,item_name,price,quantity):
        self.item_name=item_name
        self.price=price
        self.quantity=quantity
    def __str__(self):
        return f"{self.item_name}\n{self.price}\n{self.quantity}"
    def final_amount(self):
        self.price=self.price*self.quantity
        return self.price
    def __add__(self, other):
        return self.price+other.price
    def __mod__(self, discount):
        return self.price%discount
    def __lt__(self, other):
        return self.price<other.price
    def __ge__(self, other):
        return self.price>=other.price
a=CartItem("Boost",120,2)
b=CartItem("Horliks",140,3)
print(a)
print(b)
print(a+b)
print(a%5)
print(b%10)
print(a<b)
print(a>=b)

# %% [markdown]
# ---
#
# # Question 8: Time Duration
#
# Create a class `TimeDuration` with:
#
# - Attributes: `hours`, `minutes`
# - Method: `total_minutes()`
#
# Implement:
#
# - `__str__()`
# - `__add__()` → Add two time durations
# - `__sub__()` → Subtract two time durations
# - `__eq__()` → Compare total minutes
# - `__gt__()` → Check longer duration
# - `__getattr__()` → Handle invalid attribute access
# - `__setattr__()` → Minutes must be between `0` and `59`

# %%
class TimeDuration:
    def __init__(self,hours,minutes):
        self.hours=hours
        self.minutes=minutes
    def __str__(self):
        return f"{self.hours}:{self.minutes}"
    def total_minutes(self):
        self.minutes=self.minutes+(self.hours*60)
        return self.minutes
    def __add__(self, other):
        return self.minutes+other.minutes
    def __sub__(self, other):
        return self.minutes-other.minutes
    def __eq__(self, value):
        return self.minutes==value.minutes
    def __gt__(self, other):
        return self.minutes>other.minutes
a=TimeDuration(2,30)
b=TimeDuration(3,15)
print(a)
print(b)
print("total",a.total_minutes())
print("total",b.total_minutes())

print(a+b)
print(a-b)
print(a==b)
if (a>b):
    print("a is greater than b")
else:
    print("b is greater than a")

# %% [markdown]
# ---
#
# # Question 9: Laptop Specification
#
# Create a class `Laptop` with:
#
# - Attributes: `brand`, `ram`, `price`
# - Method: `upgrade_ram(extra_ram)`
#
# Implement:
#
# - `__str__()`
# - `__add__()` → Add prices of two laptops
# - `__mul__()` → Multiply price for bulk purchase
# - `__lt__()` → Compare price
# - `__eq__()` → Compare RAM
# - `__getattribute__()` → Print access message
# - `__setattr__()` → RAM and price must be positive

# %%
class Laptop:
    def __init__(self,brand,ram,price):
        self.brand=brand
        self.ram=ram
        self.price=price
    def __str__(self):
        return f"{self.brand}\n{self.ram}\n{self.price}"
    def upgrade_ram(self,extra_ram):
        self.ram=self.ram+(extra_ram)
        return self.ram

    def __add__(self, other):
        return self.price+other.price
    def __mul__(self, other):
        return self.price*other
    def __lt__(self, other):
        return self.price<other.price
    def __eq__(self,value):
        return self.ram==value.ram
a=Laptop("Hp",16,61000)
b=Laptop("Leanova",16,56000)
print(a)
print(b)
print()
print(a.upgrade_ram(4))
print(b.upgrade_ram(6))
print(a+b)
print(a*10)
print(b*20)
print(a<b)
print(a==b)

# %% [markdown]
# ---
#
# # Question 10: Game Player
#
# Create a class `Player` with:
#
# - Attributes: `name`, `health`, `attack_power`
# - Method: `attack(enemy)`
#
# Implement:
#
# - `__str__()`
# - `__add__()` → Combine attack powers
# - `__sub__()` → Reduce health after attack
# - `__gt__()` → Compare health
# - `__eq__()` → Compare attack power
# - `__getattr__()` → Return custom message for unavailable player stat
# - `__setattr__()` → Health cannot go below `0`

# %%
class Player:
    def __init__(self,name,health,attack_power):
        self.name=name
        self.health=health
        self.attack_power=attack_power
    def attack(self,enemy):
        enemy.health=enemy.health-self.attack_power
        print(enemy.name,self.name)
    def __str__(self):
        return f"\n{self.name}\n{self.health}\n{self.attack_power}"
    def __add__(self, other):
        return self.attack_power+other.attack_power
    def __sub__(self):
        return self.health-attack()
    def __gt__(self, other):
        return self.health>other.health
    def __eq__(self, value):
        return self.attack_power==value.attack_power
a=Player("Rakesh",100,75)
b=Player("Hari",120,90)
print(a,b)

Player.attack(a,b)

print(a+b)

print(a>b)
print(a==b)
# Out:
# Rakesh
# 100
# 75
# Hari
# 120
# 90
# Hari Rakesh
# 165
# True
# False

# %% [markdown]
# ---

# %% [markdown]
# # Questions On Single Level Inheritance
#
# ## 1. Bank Management System
#
# Create a `Bank` class with:
#
# - `balance` variable
# - `deposit()`
# - `withdraw()`
# - `check_balance()`
#
# Create a `User` class that inherits `Bank` and displays the user's name.
#
# Perform deposit, withdrawal, and balance check.

# %%
class Bank:
    def __init__(self,balance,holder):
        self.holder=holder
        self.balance=balance
    def deposit(self,amount):
        self.balance+=amount
       # return self.balance
    def withdraw(self,amount):
        self.balance-=amount
       # return self.balance
    def check_balance(self):
        return self.balance
class user(Bank):
    pass
a=user(20000,"Rakesh")

print(a.holder,a.balance)

a.deposit(2000)
a.withdraw(1000)
print("final balance :",a.check_balance())

# %% [markdown]
# ---
#
# ## 2. Employee Salary System
#
# Create an `Employee` class with:
#
# - `emp_name`
# - `salary`
# - `display_details()`
#
# Create a `Manager` class that inherits `Employee` and adds a `bonus()`.
#
# Display the total salary.

# %%
class Employee:
    def __init__(self,emp_name,salary):
        self.emp_name=emp_name
        self.salary=salary
    def display_details(self):
        print(self.emp_name)
        print(self.salary)
class Manager(Employee):
    def __init__(self, emp_name, salary):
        super().__init__(emp_name, salary)
        
    def bonus1(self,bonus):
        self.salary+=bonus
        print("total salary :",self.salary)
a=Manager("Vamshi",100000)
a.display_details()
a.bonus1(10000)

# %% [markdown]
# ---
#
# ## 3. Student Result System
#
# Create a `Student` class with:
#
# - `Name`
# - `marks`
# - `display_marks()`
#
# Create a `Result` class that inherits `Student` and calculates whether the student has passed or failed.

# %%
class Student:
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
    def display_marks(self):
        print("Marks :",self.marks)
class Result(Student):
    def __init__(self, name, marks):
        super().__init__(name, marks)
    def results(self):
        if self.marks >35:
            print("Pass")
        else:
            print("Fail")
a=Result("Hari",90)
print(a.name)
a.display_marks()
a.results()

# %% [markdown]
# ---

# %% [markdown]
# # Questions On Multilevel Inheritance
#
# ## 1. Food Ordering System Using Multilevel Inheritance
#
# ### Class 1: Restaurant
#
# - Create a method `menu(item)` that returns the price of the selected food item.
#
# ### Class 2: FoodCourt (inherits Restaurant)
#
# Create the following methods:
#
# - `display_menu()` – Display the available food items.
# - `order()` – Accept the food item from the user and allow multiple orders.
# - `billing()` – Display the total bill and add a packing charge of ₹20.
#
# ### Class 3: Customer (inherits FoodCourt)
#
# - Create an object of the `Customer` class.
# - Call the `order()` method.

# %%
class Restaurant:

    def menu(self, item):
        food_items = {
            "biryani" : 250,
            "pizza" : 150,
            "burger" : 200,
            "mandi" : 500,
            "friedrice" : 80
        }

        return food_items.get(item, 0)

class FoodCourt(Restaurant):

    def display_menu(self):
        print("\nAvaialable Food Items")
        print("biryani - 250")
        print("pizza - 150")
        print("burger - 200")
        print("mandi - 500")
        print("friedrice - 80")

    def order(self):
        self.total = 0
        while True:
            item=input("\nEnter Food Item").lower()
            price = self.menu(item)

            if price==0:
                print("Food item not found")
            else:
                print(item,"price is", price)
                self.total = self.total+price

            ch = input("Do you want to order again? yes/no").lower()
            if ch=="no":
                break

    def billing(self):
        delhivery_charges = 20
        print("Food Total:",self.total)
        print("Delhivery charges:", delhivery_charges)
        print("Total amount to be paid:",self.total + delhivery_charges)

class Customer(FoodCourt):
    pass

c = Customer()
c.display_menu()
c.order()
c.billing()

# %% [markdown]
# ---
#
# ## 2. Movie Ticket Booking System Using Multilevel Inheritance
#
# ### Class 1: Movie
#
# - Create a method `ticket(movie)` that returns the ticket price.
#
# ### Class 2: Booking (inherits Movie)
#
# Create the following methods:
#
# - `movies()` – Display the available movies.
# - `selection()` – Allow the user to book multiple tickets.
# - `billing()` – Display the total amount and add a booking charge of ₹30.
#
# ### Class 3: Customer (inherits Booking)
#
# - Create an object and call the `selection()` method.

# %%
class Movie:
    def ticket(self,movies):
        movies_list={
            "salar":150,
            "pushpa":550,
            "spider man":450,
            "irumudi":100,
            "rrr":350

        }
        return movies_list.get(movies,0)
class Booking(Movie):
    def moviesbooking(self):
        print("Movies--prices:")
        print("Salar -150\nPushpa -550\nSpider Man -450\nIrumudi -100\nRRR -350")
    def selection(self):
        self.total=0
        movies=input("\nEnter movie you want watch: ").lower()
        while (True):
            price=self.ticket(movies)
            if price==0:
                print("Movie Not Found")
            else:
                print(movies,"price is",price)
                self.total+=price
            ch=input("yes- for add tickets \nno -for enough tickets").lower()
            if ch=="no":
                break
    def billing(self):
        print("TOTAL AMOUNT :")
        print("total price",self.total)
        print("Total price inc.all charges:",self.total+50)
class Customer(Booking):
    pass
a=Customer()
a.moviesbooking()
a.selection()
a.billing()
# Out:
# Movies--prices:
# Salar -150
# Pushpa -550
# Spider Man -450
# Irumudi -100
# RRR -350
# rrr price is 350
# rrr price is 350
# rrr price is 350
# TOTAL AMOUNT :
# total price 1050
# Total price inc.all charges: 1100

# %% [markdown]
# ---
#
# ## 3. Online Course Enrollment System Using Multilevel Inheritance
#
# ### Class 1: Course
#
# - Create a method `fee(course)` that returns the course fee.
#
# ### Class 2: Academy (inherits Course)
#
# Create the following methods:
#
# - `courses()` – Display available courses.
# - `enroll()` – Allow the user to enroll in multiple courses.
# - `billing()` – Display the total fee and add a registration fee of ₹100.
#
# ### Class 3: Student (inherits Academy)
#
# - Create an object and call the `enroll()` method.

# %%
class Course:
    def fee(self,course):
        course_list={
            "Python FS":33000,
            "Java FS":40000,
            "Data Analyist":15000,
            "Deveops":20000
        }
        return course_list.get(course,0)
class Academy(Course):
    def courses(self):
        print("Python FS :33000\nJava FS:40000\nData Analyist:15000\nDeveops:20000")
    def enroll(self):
        self.total=0
        course=input("\nEnter the Course that your intrested in:").lower()
        while(True):
            price=self.fee(course_list)
            if price==0:
                print("The course is not avaliable or invalid input")
            else:
                print(course,"course price is",price)
                self.total+=price
            ch=input("Yes if ur wanna take another course also,else no").lower()
            if ch=="no":
                break
class enrolling(Academy):
    pass
a=enrolling()
a.courses

# %% [markdown]
# ---

# %%
class Restaurant:

    def menu(self, item):
        food_items = {
            "biryani" : 250,
            "pizza" : 150,
            "burger" : 200,
            "mandi" : 500,
            "friedrice" : 80
        }

        return food_items.get(item, 0)

class FoodCourt(Restaurant):

    def display_menu(self):
        print("\nAvaialable Food Items")
        print("biryani - 250")
        print("pizza - 150")
        print("burger - 200")
        print("mandi - 500")
        print("friedrice - 80")

    def order(self):
        self.total = 0
        while True:
            item=input("\nEnter Food Item").lower()
            price = self.menu(item)

            if price==0:
                print("Food item not found")
            else:
                print(item,"price is", price)
                self.total = self.total+price

            ch = input("Do you want to order again? yes/no").lower()
            if ch=="no":
                break

    def billing(self):
        delhivery_charges = 20
        print("Food Total:",self.total)
        print("Delhivery charges:", delhivery_charges)
        print("Total amount to be paid:",self.total + delhivery_charges)

class Customer(FoodCourt):
    pass

c = Customer()
c.display_menu()
c.order()
c.billing()

# %%
# Questions On Generator
# 1.	Write a generator that yields numbers from 1 to N.
# 2.	Write a generator that yields even numbers from 1 to N
# 3.	Write a generator that yields each character of a string.
# 4.	Write a generator that yields characters of a string in reverse order.
# 5.	Write a generator that yields only vowels from a string.
# 6.	Write a generator that yields only digits present in a string.
# 7.	Write a generator that yields the square of each element in a list.
# 8.	Write a generator that yields digits from an integer one by one.
# 9.	Create a generator that yields cumulative sum of numbers in a list. Example: [1,2,3] → 1, 3, 6

# %%
def gen(start):
    rev=0
    while(start!=0):
        r=start%10
        
        start=start//10
        yield r
 
    
a=126
for i in gen(a):
    print(i)
# Out:
# 6
# 2
# 1

# %%
def gen(start):
    index=0
    while(index<len(start)):
        value=start[index]
        index+=1
        yield value
a="Rakesh1265"
for i in gen(list(a)):
    print(i)

# %%
def gen(start):
    index=0
    while(index<len(start)):
        value=start[index]
        index+=1
        yield value
a="Rakesh"
for i in gen(list(a)):
    print(i)
# Out:
# R
# a
# k
# e
# s
# h

# %%
def gen(start):
    index=0
    while(index<len(start)):
        if start[index] in "0123456789":
            value=start[index]
            
            yield value
        index+=1
    
a="Rakesh201265"
for i in gen(list(a)):
    print(i)
# Out:
# 2
# 0
# 1
# 2
# 6
# 5

# %%
def gen(start):
    index=-1
    while(index>=-(len(start))):
        value=start[index]
        index-=1
        yield value
a="Rakesh"
for i in gen(list(a)):
    print(i)
# Out:
# h
# s
# e
# k
# a
# R

# %%
def ern(start,end):
    value=0
    while(start<=end):
        value=start
        yield value
        start+=1
n=int(input())
for i in ern(1,n):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
class counter:
    def __init__(self,start,end):
        self.current=start
        self.end=end
    def __str__(self):
        return self
    def __iter__(self):
        return self
    def __next__(self):
        while(self.current<=self.end):
            value=self.current
            self.current+=1
            return value
        raise StopIteration
for i in counter(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
def ern(start,end):
    value=0
    while(start<=end):
        if start%2==0:
            value=start
            yield value
        start+=1
n=int(input())
for i in ern(1,n):
    print(i)
# Out:
# 2
# 4
# 6

# %%
class Employee:

    def __init__(self,name,age,salary):
        self.name = name
        self._age=age
        self.__salary = salary

    @property
    def salary(self):
        return self.__salary

    @salary.setter
    def salary(self,new_salary):
        self.__salary = new_salary

e = Employee("jhon",20,10000)
print("before updating salary",e.salary)
e.salary = 20000
print("after updating salary",e.salary)
# Out:
# before updating salary 10000
# after updating salary 20000

# %% [markdown]
# # Questions on Setter and Getter Methods
#
# ## 1. Student Class — Private `__marks`
#
# Create a `Student` class with a private variable `__marks`.
#
# Create methods:
#
# - `set_marks()` → to assign marks
# - `get_marks()` → to retrieve marks
#
# Create an object and access the marks using these methods.
#
# ### Answer:

# %%
class Student:
    def __init__(self,marks):
        self.__marks=marks
    def set_marks(self,new):
        self.__marks=new
    def get_marks(self):
        return self.__marks
a=Student(98)
a.set_marks(100)
print(a.get_marks())
# Out:
# 100

# %% [markdown]
# ## 2. BankAccount Class — Private `__balance`
#
# Create a `BankAccount` class with a private variable `__balance`.
#
# Implement:
#
# - `deposit(amount)`
# - `withdraw(amount)`
# - `get_balance()`
#
# The balance should not be accessed directly from outside the class.
#
# ### Answer:
